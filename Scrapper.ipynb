# %%
import requests
from contextlib import closing
from bs4 import BeautifulSoup
import logging
import datetime
import csv
import pandas as pd
import WebReader as wr
import Data_cleaning as dc


forcal = []


def append_day_info(startlink):
    # Takes url representing certain day as parameter
    # Appends day info to forcal list

    table = wr.parse_content(startlink, 'table', 'calendar__table')
        # do not use the ".calendar__row--grey" css selector (reserved for historical data)
    trs = table.select("tr.calendar__row.calendar_row")
    fields = ["date","time","currency","impact","event","actual","forecast","previous"]
    # some rows do not have a date (cells merged)
    curr_year = startlink[-4:]
    curr_date = ""
    curr_time = ""
    for tr in trs:
        dict = {}
        # fields may mess up sometimes, see Tue Sep 25 2:45AM French Consumer Spending
        # in that case we append to errors.csv the date time where the error is
        try:
            for field in fields:
                data = tr.select("td.calendar__cell.calendar__{}.{}".format(field,field))[0]
                # print(data)
                if field=="date" and data.text.strip()!="":
                    curr_date = data.text.strip()
                elif field=="time" and data.text.strip()!="":
                    # time is sometimes "All Day" or "Day X" (eg. WEF Annual Meetings)
                    if data.text.strip().find("Day")!=-1:
                        curr_time = "12:00am"
                    else:
                        curr_time = data.text.strip()
                elif field=="currency":
                    currency = data.text.strip()
                elif field=="impact":
                    # when impact says "Non-Economic" on mouseover, the relevant
                    # class name is "Holiday", thus we do not use the classname
                    impact = data.find("span")["title"]
                elif field=="event":
                    event = data.text.strip()
                elif field=="actual":
                    actual = data.text.strip()
                elif field=="forecast":
                    forecast = data.text.strip()
                elif field=="previous":
                    previous = data.text.strip()
            date = datetime.datetime.strptime(",".join([curr_year,curr_date,curr_time]),"%Y,%a%b %d,%I:%M%p")
            # date = datetime.datetime.strptime(",".join([curr_year,curr_date,curr_time]),"%Y,%a%b %d,%I:%M%p")
            # date = datetime.datetime.strptime(",".join([curr_year,curr_date]),"%Y,%a%b")
            # time = datetime.datetime.strptime(curr_time, "%d,%I:%M%p")
            dict["Date"] = date.strftime("%Y-%m-%d %H:%M:%S")
            dict["Currency"] = currency
            dict["Impact"] = impact
            dict["Event"] = event
            dict["Actual"] = actual
            dict["Forecast"] = forecast
            dict["Previous"] = previous
            forcal.append(dict)
            # forcal.append(",".join([str(dt),currency,impact,event,actual,forecast,previous]))
        except:
            with open("errors.csv","a") as f:
                csv.writer(f).writerow([curr_year,curr_date,curr_time])


def getEconomicCalendar(startlink,endlink):
    # Function takes interval of days for which to scrape data
    # Scrapes for each day

    # write to console current status
    logging.info("Scraping data for link: {}".format(startlink))
    append_day_info(startlink)

    # exit recursion when last available link has reached
    if startlink == endlink:
        logging.info("Successfully retrieved data")
        #result_DF = pd.DataFrame(forcal)
        #print(result_DF)
        return pd.DataFrame(forcal)

    data = wr.get_url_content(startlink)
    soup = BeautifulSoup(data, "html.parser")
    # get the link for the next week and follow

    follow = soup.select("a.calendar__pagination.calendar__pagination--next.next")
    follow = 'https://www.forexfactory.com/' + follow[0]["href"]
    getEconomicCalendar(follow,endlink)


def setLogger():
    # Logs and presents status

    logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    filename='logs_file',
                    filemode='w')
    console = logging.StreamHandler()
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    console.setFormatter(formatter)
    logging.getLogger('').addHandler(console)


if __name__ == '__main__':
    
    print('Main starts')
    setLogger()
    getEconomicCalendar('https://www.forexfactory.com/calendar?day=apr1.2020', 'https://www.forexfactory.com/calendar?day=apr3.2020')
    data = pd.DataFrame(forcal)
    print('test:', data)
    print(dc.cleaning_data(data, 'Forecast'))
    print(dc.chg_type_and_cleaning_ch(data, 'Forecast'))
    print(dc.filtration(data, 'Currency', 'EUR', 'Impact', 'Low'))
# Out:
# 2020-05-02 10:15:44,964 - INFO - Scraping data for link: https://www.forexfactory.com/calendar?day=apr1.2020
# Main starts
# 2020-05-02 10:15:47,112 - INFO - Scraping data for link: https://www.forexfactory.com/calendar?day=apr2.2020
# 2020-05-02 10:15:49,231 - INFO - Scraping data for link: https://www.forexfactory.com/calendar?day=apr3.2020
# 2020-05-02 10:15:50,275 - INFO - Successfully retrieved data
# test:                    Date Currency                  Impact  \
# 0   2020-04-01 01:30:00      AUD     Low Impact Expected
# 1   2020-04-01 02:00:00      EUR     Low Impact Expected
# 2   2020-04-01 03:15:00      EUR     Low Impact Expected
# 3   2020-04-01 03:30:00      CHF     Low Impact Expected
# 4   2020-04-01 03:45:00      EUR     Low Impact Expected
# 5   2020-04-01 03:50:00      EUR     Low Impact Expected
# 6   2020-04-01 03:55:00      EUR     Low Impact Expected
# 7   2020-04-01 04:00:00      EUR     Low Impact Expected
# 8   2020-04-01 04:00:00      EUR     Low Impact Expected
# 9   2020-04-01 04:30:00      GBP     Low Impact Expected
# 10  2020-04-01 05:00:00      EUR     Low Impact Expected
# 11  2020-04-01 08:15:00      USD    High Impact Expected
# 12  2020-04-01 09:30:00      CAD     Low Impact Expected
# 13  2020-04-01 09:45:00      USD     Low Impact Expected
# 14  2020-04-01 10:00:00      USD    High Impact Expected
# 15  2020-04-01 10:00:00      USD     Low Impact Expected
# 16  2020-04-01 10:00:00      USD     Low Impact Expected
# 17  2020-04-01 00:00:00      USD     Low Impact Expected
# 18  2020-04-01 10:30:00      USD     Low Impact Expected
# 19  2020-04-01 17:37:00      USD    High Impact Expected
# 20  2020-04-01 19:50:00      JPY     Low Impact Expected
# 21  2020-04-01 20:30:00      AUD     Low Impact Expected
# 22  2020-04-01 23:35:00      JPY     Low Impact Expected
# 23  2020-04-02 02:00:00      GBP     Low Impact Expected
# 24  2020-04-02 02:30:00      CHF     Low Impact Expected
# 25  2020-04-02 03:00:00      EUR     Low Impact Expected
# 26  2020-04-02 04:53:00      EUR     Low Impact Expected
# 27  2020-04-02 04:59:00      EUR     Low Impact Expected
# 28  2020-04-02 05:00:00      EUR     Low Impact Expected
# 29  2020-04-02 07:30:00      USD     Low Impact Expected
# 30  2020-04-02 08:30:00      CAD  Medium Impact Expected
# 31  2020-04-02 08:30:00      USD    High Impact Expected
# 32  2020-04-02 08:30:00      USD     Low Impact Expected
# 33  2020-04-02 10:00:00      USD     Low Impact Expected
# 34  2020-04-02 10:30:00      USD     Low Impact Expected
# 35  2020-04-02 17:23:00      USD    High Impact Expected
# 49  2020-04-03 08:30:00      USD    High Impact Expected
# 50  2020-04-03 09:45:00      USD     Low Impact Expected
# 51  2020-04-03 10:00:00      USD  Medium Impact Expected
#
#                                 Event  Actual Forecast Previous
# 1             German Retail Sales m/m    1.2%     0.1%     1.0%
# 2           Spanish Manufacturing PMI    45.7     44.0     50.4
# 3                   Manufacturing PMI    43.7     42.3     49.5
# 4           Italian Manufacturing PMI    40.3     41.1     48.7
# 5      French Final Manufacturing PMI    43.2     42.9     42.9
# 6      German Final Manufacturing PMI    45.4     45.6     45.7
# 7             Final Manufacturing PMI    44.5     44.7     44.8
# 8   Italian Monthly Unemployment Rate    9.7%    10.0%     9.8%
# 9             Final Manufacturing PMI    47.8     47.1     48.0
# 10                  Unemployment Rate    7.3%     7.4%     7.4%
# 11     ADP Non-Farm Employment Change    -27K    -150K     179K
# 13            Final Manufacturing PMI    48.5     48.2     49.2
# 14              ISM Manufacturing PMI    49.1     44.9     50.1
# 15          Construction Spending m/m   -1.3%     0.6%     2.8%
# 16           ISM Manufacturing Prices    37.4     41.6     45.9
# 17          Wards Total Vehicle Sales   11.4M    12.2M    16.8M
# 18              Crude Oil Inventories   13.8M     3.7M     1.6M
# 20                  Monetary Base y/y    2.8%     3.5%     3.6%
# 23                 Nationwide HPI m/m    0.8%     0.0%     0.3%
# 24                            CPI m/m    0.1%     0.1%     0.1%
# 25        Spanish Unemployment Change  302.3K    27.7K    -7.8K
# 28                            PPI m/m   -0.6%    -0.3%     0.2%
# 30                      Trade Balance   -1.0B    -2.3B    -1.7B
# 31                Unemployment Claims   6648K    3600K    3307K
# 32                      Trade Balance  -39.9B   -40.6B   -45.5B
# 33                 Factory Orders m/m    0.0%     0.2%    -0.5%
# 34                Natural Gas Storage    -19B     -31B     -29B
# 37                   Retail Sales m/m    0.5%     0.4%     0.4%
# 38                Caixin Services PMI    43.0     39.6     26.5
# 40               Spanish Services PMI    23.0     25.6     52.1
# 41               Italian Services PMI    17.4     22.4     52.1
# 42          French Final Services PMI    27.4     29.0     29.0
# 43          German Final Services PMI    31.7     34.3     34.5
# 44                 Final Services PMI    26.4     28.2     28.4
# 45                 Final Services PMI    34.5     34.7     35.7
# 46                   Retail Sales m/m    0.9%     0.1%     0.7%
# 47        Average Hourly Earnings m/m    0.4%     0.2%     0.3%
# 48         Non-Farm Employment Change   -701K    -100K     275K
# 49                  Unemployment Rate    4.4%     3.8%     3.5%
# 50                 Final Services PMI    39.8     38.7     39.1
# 51          ISM Non-Manufacturing PMI    52.5     43.5     57.3
#                    Date Currency                  Impact  \
# 1   2020-04-01 02:00:00      EUR     Low Impact Expected
# 2   2020-04-01 03:15:00      EUR     Low Impact Expected
# 3   2020-04-01 03:30:00      CHF     Low Impact Expected
# 4   2020-04-01 03:45:00      EUR     Low Impact Expected
# 5   2020-04-01 03:50:00      EUR     Low Impact Expected
# 6   2020-04-01 03:55:00      EUR     Low Impact Expected
# 7   2020-04-01 04:00:00      EUR     Low Impact Expected
# 8   2020-04-01 04:00:00      EUR     Low Impact Expected
# 9   2020-04-01 04:30:00      GBP     Low Impact Expected
# 25        Spanish Unemployment Change  302.3K      27.7    -7.8K
# 28                            PPI m/m   -0.6%       0.3     0.2%
# 30                      Trade Balance   -1.0B       2.3    -1.7B
# 31                Unemployment Claims   6648K    3600.0    3307K
# 32                      Trade Balance  -39.9B      40.6   -45.5B
# 33                 Factory Orders m/m    0.0%       0.2    -0.5%
# 34                Natural Gas Storage    -19B      31.0     -29B
# 37                   Retail Sales m/m    0.5%       0.4     0.4%
# 38                Caixin Services PMI    43.0      39.6     26.5
# 40               Spanish Services PMI    23.0      25.6     52.1
# 41               Italian Services PMI    17.4      22.4     52.1
# 42          French Final Services PMI    27.4      29.0     29.0
# 43          German Final Services PMI    31.7      34.3     34.5
# 44                 Final Services PMI    26.4      28.2     28.4
# 45                 Final Services PMI    34.5      34.7     35.7
# 46                   Retail Sales m/m    0.9%       0.1     0.7%
# 47        Average Hourly Earnings m/m    0.4%       0.2     0.3%
# 48         Non-Farm Employment Change   -701K     100.0     275K
# 49                  Unemployment Rate    4.4%       3.8     3.5%
# 50                 Final Services PMI    39.8      38.7     39.1
# 51          ISM Non-Manufacturing PMI    52.5      43.5     57.3
#                    Date Currency               Impact  \
# 1   2020-04-01 02:00:00      EUR  Low Impact Expected
# 2   2020-04-01 03:15:00      EUR  Low Impact Expected
# 4   2020-04-01 03:45:00      EUR  Low Impact Expected
# 5   2020-04-01 03:50:00      EUR  Low Impact Expected
# 6   2020-04-01 03:55:00      EUR  Low Impact Expected
# 7   2020-04-01 04:00:00      EUR  Low Impact Expected
# 8   2020-04-01 04:00:00      EUR  Low Impact Expected
# 10  2020-04-01 05:00:00      EUR  Low Impact Expected
# 25  2020-04-02 03:00:00      EUR  Low Impact Expected
# 28  2020-04-02 05:00:00      EUR  Low Impact Expected
# 40  2020-04-03 03:15:00      EUR  Low Impact Expected
# 41  2020-04-03 03:45:00      EUR  Low Impact Expected
# 42  2020-04-03 03:50:00      EUR  Low Impact Expected
# 43  2020-04-03 03:55:00      EUR  Low Impact Expected
# 44  2020-04-03 04:00:00      EUR  Low Impact Expected
# 46  2020-04-03 05:00:00      EUR  Low Impact Expected
#
#                                 Event  Actual  Forecast Previous
# 1             German Retail Sales m/m    1.2%       0.1     1.0%
# 2           Spanish Manufacturing PMI    45.7      44.0     50.4
# 4           Italian Manufacturing PMI    40.3      41.1     48.7
# 5      French Final Manufacturing PMI    43.2      42.9     42.9
# 6      German Final Manufacturing PMI    45.4      45.6     45.7
# 7             Final Manufacturing PMI    44.5      44.7     44.8
# 8   Italian Monthly Unemployment Rate    9.7%      10.0     9.8%
# 10                  Unemployment Rate    7.3%       7.4     7.4%
# 25        Spanish Unemployment Change  302.3K      27.7    -7.8K
# 28                            PPI m/m   -0.6%       0.3     0.2%
# 40               Spanish Services PMI    23.0      25.6     52.1
# 41               Italian Services PMI    17.4      22.4     52.1
# 42          French Final Services PMI    27.4      29.0     29.0
# 43          German Final Services PMI    31.7      34.3     34.5
# 44                 Final Services PMI    26.4      28.2     28.4
# 46                   Retail Sales m/m    0.9%       0.1     0.7%
